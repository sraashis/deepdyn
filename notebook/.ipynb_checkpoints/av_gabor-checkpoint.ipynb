# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\idea projects\\pycharm projects\\ature\\notebook'

# %%
os.chdir("D:\\idea projects\\pycharm projects\\ature\\")

# %%
import preprocess.av.av_utils as av
from preprocess.common.mat_utils import Mat
import preprocess.filter.image_filters as imf
import preprocess.graph.graph_utils as gt
import preprocess.image.image_utils as img
import matplotlib.pyplot as plt

# %%
file = Mat(file_name='wide_image_13.mat')

# %%
image_array = file.get_image('I2')

# %%
av.show_av_graph(av_data_set=file,av_only=True,onh_show=True,image_show=True)

# %%
import preprocess.filter.image_filters as fil

# %%
kernels = fil.build_filter_bank(k_size_start=4, k_size_end=11, k_step=1, gamma=0.1)
fil.show_kernels(kernels=kernels,save_fig=False)

# %%
arr
# Out:
# array([[   9.86305622,   48.72577286,  125.10676383,  202.31121915,
#          234.89976638,  202.31121915,  125.10676383,   48.72577286,
#            9.86305622],
#        [   5.69922793,   46.7464372 ,  127.42084166,  208.9649978 ,
#          243.38536349,  208.9649978 ,  127.42084166,   46.7464372 ,
#            5.69922793],
#        [   2.58252203,   45.26486622,  129.15297361,  213.94547965,
#          249.73699683,  213.94547965,  129.15297361,   45.26486622,
#            2.58252203],
#        [   0.65321608,   44.34774289,  130.22519942,  217.02850179,
#          253.66879033,  217.02850179,  130.22519942,   44.34774289,
#            0.65321608],
#        [   0.        ,   44.03722724,  130.588229  ,  218.07233811,
#          255.        ,  218.07233811,  130.588229  ,   44.03722724,    0.        ],
#        [   0.65321608,   44.34774289,  130.22519942,  217.02850179,
#          253.66879033,  217.02850179,  130.22519942,   44.34774289,
#            0.65321608],
#        [   2.58252203,   45.26486622,  129.15297361,  213.94547965,
#          249.73699683,  213.94547965,  129.15297361,   45.26486622,
#            2.58252203],
#        [   5.69922793,   46.7464372 ,  127.42084166,  208.9649978 ,
#          243.38536349,  208.9649978 ,  127.42084166,   46.7464372 ,
#            5.69922793],
#        [   9.86305622,   48.72577286,  125.10676383,  202.31121915,
#          234.89976638,  202.31121915,  125.10676383,   48.72577286,
#            9.86305622]])

# %%
img.from_array(image_array[:, :, 1])
# Out:
# <PIL.Image.Image image mode=L size=1531x829 at 0x1F680698908>

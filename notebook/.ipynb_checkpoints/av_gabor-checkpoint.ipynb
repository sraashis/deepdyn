# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\idea projects\\pycharm projects\\ature\\notebook'

# %%
os.chdir("D:\\idea projects\\pycharm projects\\ature\\")

# %%
import preprocess.av.av_utils as av
from preprocess.common.mat_utils import Mat
import preprocess.filter.image_filters as imf
import preprocess.graph.graph_utils as gt
import preprocess.image.image_utils as img
import matplotlib.pyplot as plt

# %%
file = Mat(file_name='wide_image_03.mat')

# %%
image_array = file.get_image('I2')

# %%
av.show_av_graph(av_data_set=file,av_only=True,onh_show=True,image_show=True)

# %%
import preprocess.filter.image_filters as fil

# %%
kernels = fil.build_filter_bank(k_size=24, lambd=5.01, sigma=1.79, psi=0.0, gamma=.89)
final_image = fil.process(image_array[:, :, 1], kernels)
img.from_array(image_array[:, :, 1])
# Out:
# <PIL.Image.Image image mode=L size=1551x937 at 0x209C9A54CF8>

# %%
img.from_array(final_image)
# Out:
# <PIL.Image.Image image mode=L size=1551x937 at 0x209C9BB1BE0>

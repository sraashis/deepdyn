# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\idea projects\\pycharm projects\\ature\\notebook'

# %%
os.chdir("D:\\idea projects\\pycharm projects\\ature\\")

# %%
import preprocess.av.av_utils as av
from preprocess.common.mat_utils import Mat
import preprocess.filter.image_filters as imf
import preprocess.graph.graph_utils as gt
import preprocess.image.image_utils as img
import matplotlib.pyplot as plt
import os
import path_config as pth
import numpy as np
import preprocess.filter.image_filters as fil

import joblib as jlb
import path_config as cfg

file = Mat(file_name=str('wide_image_03.mat'))
img_arr = file.get_image('I2')[:,:,1]
kernels = []

# %%
final_img = fil.apply_bilateral(img_arr,k_size=17)

# %%
os.chdir(cfg.out_data_set)

# %%
kern = jlb.load('kern.pkl')

# %%
final_img = fil.apply_gabor(final_img,bank=kern)

# %%
img.from_array(final_img)
# Out:
# <PIL.Image.Image image mode=L size=1551x937 at 0x2656D01B240>

# %%
img.histogram(final_img)

# %%
final_img[final_img>5] = 255
img.from_array(final_img)
# Out:
# <PIL.Image.Image image mode=L size=1551x937 at 0x1E04FDB0630>

# %%
img.histogram(final_img)

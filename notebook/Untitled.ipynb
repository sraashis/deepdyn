# %%
import numpy as np

# %%
a = np.array([[1,2], [2,3], [3,4]])

# %%
a[:-1]
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
a[-1][]
# Out:
# array([3, 4])

# %%
b = np.array([[4, 6]])

# %%
np.append(a, a[-1][None,...], 0)
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4],
#        [3, 4]])

# %%
a[-1][None, ...]
# Out:
# array([[3, 4]])

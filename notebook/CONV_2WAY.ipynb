# %% [markdown]
# ### Initialize notebook

# %%
# Torch imports
import torch
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.dataset import Dataset
import PIL.Image as IMG
from torch.utils.data.sampler import WeightedRandomSampler

# Other imports
import matplotlib.pyplot as plt
import numpy as np
import os
os.chdir('/home/ak/Spring2018/ature')
from neuralnet.utils.datasets import  DriveDatasetFromFile, DriveDatasetFromImageObj

import utils.img_utils as imgutil
from commons.IMAGE import SegmentedImage
from neuralnet.trainer import NNTrainer
import neuralnet.utils.measurements as mnt

sep = os.sep

# Define folders (create them if needed)
Dirs = {}
Dirs['train_data']      = 'data'+sep+'DRIVE'+sep+'training'+sep +'patches'

Dirs['data']      = 'data'+sep+'DRIVE'+sep+'test'
Dirs['images']    = Dirs['data'] +sep+ 'images'
Dirs['mask']      = Dirs['data'] +sep+ 'mask'
Dirs['truth']     = Dirs['data'] +sep+ '1st_manual'
Dirs['segmented'] = Dirs['data'] +sep+ 'drive_segmented'
Dirs['test_data'] = Dirs['data'] +sep+ 'patches'
Dirs['checkpoint']   = 'data' +sep+ 'checkpoint'

for k, folder in Dirs.items():
    os.makedirs(folder, exist_ok=True)

# Set up execution flags
Flags = {}
Flags['useGPU'] = False

classes = ('bground', 'vessel')

# %% [markdown]
# ### Define the network

# %%
class Net(nn.Module):
    def __init__(self, width, channels):
        super(Net, self).__init__()
        
        self.channels = channels
        self.width = width
        
    
        self.kern_size = 5
        self.kern_stride = 2      
        self.kern_padding = 2
        self.mxp_kern_size = 2
        self.mxp_stride = 2 
        self.pool1 = nn.MaxPool2d(kernel_size=self.mxp_kern_size, stride=self.mxp_stride)
        self.conv1 = nn.Conv2d(self.channels, 20, self.kern_size, 
                               stride=self.kern_stride, padding=self.kern_padding)
        self._update_output_size()
        
        
        self.kern_size = 5
        self.kern_stride = 1      
        self.kern_padding = 2
        self.mxp_kern_size = 1
        self.mxp_stride = 1 
        self.pool2 = nn.MaxPool2d(kernel_size=self.mxp_kern_size, stride=self.mxp_stride)
        self.conv2 = nn.Conv2d(20, 50, self.kern_size, 
                               stride=self.kern_stride, padding=self.kern_padding)
        self._update_output_size()
        
        
        self.kern_size = 5
        self.kern_stride = 1      
        self.kern_padding = 1
        self.mxp_kern_size = 1
        self.mxp_stride = 1 
        self.pool3 = nn.MaxPool2d(kernel_size=self.mxp_kern_size, stride=self.mxp_stride)
        self.conv3 = nn.Conv2d(50, 50, self.kern_size, 
                               stride=self.kern_stride, padding=self.kern_padding)
        self._update_output_size()
        
        
        
        self.linearWidth = 50*int(self.width)*int(self.width)
        self.fc1 = nn.Linear(self.linearWidth, 100)
        self.fc2 = nn.Linear(100, 20)
        self.fc3 = nn.Linear(20, 4)
        self.sm = nn.LogSoftmax(dim=1)

    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.pool3(F.relu(self.conv3(x)))
        x = x.view(-1, self.linearWidth)
        x = F.dropout(x, training=self.training)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def _update_output_size(self):       
        temp = self.width
        self.width = ((self.width - self.kern_size + 2 * self.kern_padding) / self.kern_stride) + 1
        temp1 = self.width
        self.width = ((self.width - self.mxp_kern_size)/self.mxp_stride) + 1
        print('output width { ' + str(temp) + ' -conv-> ' + str(temp1) + ' -maxpool-> ' + str(self.width) + ' }')

width = 31
channels = 1
net = Net(width, channels)
optimizer = optim.Adam(net.parameters(), lr=0.0001)
# Out:
# output width { 31 -conv-> 16.0 -maxpool-> 8.0 }
# output width { 8.0 -conv-> 8.0 -maxpool-> 8.0 }
# output width { 8.0 -conv-> 6.0 -maxpool-> 6.0 }

# %% [markdown]
# ### Load training dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor()])

trainset = DriveDatasetFromFile(data_path=Dirs['train_data'], height=31, width=31,
                                num_classes=2, transform=transform)
clss, class_counts = np.unique(trainset.labels, return_counts=True)
class_weights = 1.0/class_counts
data_weights = np.array([class_weights[t] for t in trainset.labels]) 
min_class_count =  np.partition(class_counts, 0)[0]

sampler = WeightedRandomSampler(data_weights, int(min_class_count))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=30, shuffle=False, num_workers=3, sampler=sampler)
print(min_class_count)
# Out:
# Data file loaded: data/DRIVE/training/patches/25_training.npy
# Data file loaded: data/DRIVE/training/patches/37_training.npy
# Data file loaded: data/DRIVE/training/patches/35_training.npy
# Data file loaded: data/DRIVE/training/patches/38_training.npy
# Data file loaded: data/DRIVE/training/patches/34_training.npy
# ERROR loading data/DRIVE/training/patches/39_training.npy : cannot reshape array of size 122240896 into shape (189055,962)
# Data file loaded: data/DRIVE/training/patches/24_training.npy
# Data file loaded: data/DRIVE/training/patches/27_training.npy
# Data file loaded: data/DRIVE/training/patches/33_training.npy
# Data file loaded: data/DRIVE/training/patches/26_training.npy
# Data file loaded: data/DRIVE/training/patches/31_training.npy
# Data file loaded: data/DRIVE/training/patches/23_training.npy
# Data file loaded: data/DRIVE/training/patches/29_training.npy
# Data file loaded: data/DRIVE/training/patches/28_training.npy
# 333971

# %% [markdown]
# ### Load test dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor()])

testset = DriveDatasetFromFile(data_path=Dirs['test_data'], height=31, width=31, 
                               transform=transform, num_classes=2)

clss_test, class_counts_test = np.unique(testset.labels, return_counts=True)
class_weights_test = 1.0/class_counts_test

data_weights_test = np.array([class_weights_test[t] for t in testset.labels])

min_class_count_test =  np.partition(class_counts_test, 0)[0]

sampler_test = WeightedRandomSampler(data_weights_test, int(min_class_count_test))
testloader = torch.utils.data.DataLoader(testset, batch_size=2, shuffle=False, num_workers=3, sampler=sampler_test)
print(min_class_count_test)
# Out:
# Data file loaded: data/DRIVE/test/patches/02_test.npy
# Data file loaded: data/DRIVE/test/patches/16_test.npy
# Data file loaded: data/DRIVE/test/patches/06_test.npy
# Data file loaded: data/DRIVE/test/patches/13_test.npy
# Data file loaded: data/DRIVE/test/patches/15_test.npy
# Data file loaded: data/DRIVE/test/patches/05_test.npy
# Data file loaded: data/DRIVE/test/patches/19_test.npy
# Data file loaded: data/DRIVE/test/patches/14_test.npy
# 210843

# %% [markdown]
# ### Train and evaluate the network

# %%
trainer = NNTrainer(model=net, checkpoint_dir=Dirs['checkpoint'], checkpoint_file='checkpoint2Way.nn.tar')
trainer.train(optimizer=optimizer, dataloader=trainloader, epochs=2, use_gpu=Flags['useGPU'])
# trainer.resume_from_checkpoint()
acc, y_pred, y_true = trainer.test(dataloader=testloader, use_gpu=Flags['useGPU'], force_checkpoint=False)
# trainer.test()
# Out:
# [epoch: 1, batches: 133] loss: 0.897
# [epoch: 1, batches: 266] loss: 0.713
# [epoch: 1, batches: 399] loss: 0.700
# [epoch: 1, batches: 532] loss: 0.693
# [epoch: 1, batches: 665] loss: 0.632
# [epoch: 1, batches: 798] loss: 0.571
# [epoch: 1, batches: 931] loss: 0.552
# [epoch: 1, batches: 1064] loss: 0.524
# [epoch: 1, batches: 1197] loss: 0.495
# [epoch: 1, batches: 1330] loss: 0.484
# [epoch: 1, batches: 1463] loss: 0.457
# [epoch: 1, batches: 1596] loss: 0.452
# [epoch: 1, batches: 1729] loss: 0.440
# [epoch: 1, batches: 1862] loss: 0.451
# [epoch: 1, batches: 1995] loss: 0.445
# [epoch: 1, batches: 2128] loss: 0.444
# [epoch: 1, batches: 2261] loss: 0.427
# [epoch: 1, batches: 2394] loss: 0.436
# [epoch: 1, batches: 2527] loss: 0.427
# [epoch: 1, batches: 2660] loss: 0.429
# [epoch: 1, batches: 2793] loss: 0.408
# [epoch: 1, batches: 2926] loss: 0.406
# [epoch: 1, batches: 3059] loss: 0.385
# [epoch: 1, batches: 3192] loss: 0.379
# [epoch: 1, batches: 3325] loss: 0.364
# [epoch: 1, batches: 3458] loss: 0.366
# [epoch: 1, batches: 3591] loss: 0.375
# [epoch: 1, batches: 3724] loss: 0.371
# [epoch: 1, batches: 3857] loss: 0.368
# [epoch: 1, batches: 3990] loss: 0.376
# [epoch: 1, batches: 4123] loss: 0.349
# [epoch: 1, batches: 4256] loss: 0.353
# [epoch: 1, batches: 4389] loss: 0.357
# [epoch: 1, batches: 4522] loss: 0.352
# [epoch: 1, batches: 4655] loss: 0.359
# [epoch: 1, batches: 4788] loss: 0.354
# [epoch: 1, batches: 4921] loss: 0.337
# [epoch: 1, batches: 5054] loss: 0.340
# [epoch: 1, batches: 5187] loss: 0.337
# [epoch: 1, batches: 5320] loss: 0.337
# [epoch: 1, batches: 5453] loss: 0.343
# [epoch: 1, batches: 5586] loss: 0.340
# [epoch: 1, batches: 5719] loss: 0.327
# [epoch: 1, batches: 5852] loss: 0.339
# [epoch: 1, batches: 5985] loss: 0.315
# [epoch: 1, batches: 6118] loss: 0.342
# [epoch: 1, batches: 6251] loss: 0.319
# [epoch: 1, batches: 6384] loss: 0.341
# [epoch: 1, batches: 6517] loss: 0.329
# [epoch: 1, batches: 6650] loss: 0.341
# [epoch: 1, batches: 6783] loss: 0.315
# [epoch: 1, batches: 6916] loss: 0.341
# [epoch: 1, batches: 7049] loss: 0.313
# [epoch: 1, batches: 7182] loss: 0.327
# [epoch: 1, batches: 7315] loss: 0.329
# [epoch: 1, batches: 7448] loss: 0.332
# [epoch: 1, batches: 7581] loss: 0.317
# [epoch: 1, batches: 7714] loss: 0.313
# [epoch: 1, batches: 7847] loss: 0.305
# [epoch: 1, batches: 7980] loss: 0.308
# [epoch: 1, batches: 8113] loss: 0.318
# [epoch: 1, batches: 8246] loss: 0.308
# [epoch: 1, batches: 8379] loss: 0.328
# [epoch: 1, batches: 8512] loss: 0.315
# [epoch: 1, batches: 8645] loss: 0.310
# [epoch: 1, batches: 8778] loss: 0.331
# [epoch: 1, batches: 8911] loss: 0.296
# [epoch: 1, batches: 9044] loss: 0.306
# [epoch: 1, batches: 9177] loss: 0.306
# [epoch: 1, batches: 9310] loss: 0.293
# [epoch: 1, batches: 9443] loss: 0.309
# [epoch: 1, batches: 9576] loss: 0.307
# [epoch: 1, batches: 9709] loss: 0.293
# [epoch: 1, batches: 9842] loss: 0.306
# [epoch: 1, batches: 9975] loss: 0.321
# [epoch: 1, batches: 10108] loss: 0.307
# [epoch: 1, batches: 10241] loss: 0.315
# [epoch: 1, batches: 10374] loss: 0.298
# [epoch: 1, batches: 10507] loss: 0.286
# [epoch: 1, batches: 10640] loss: 0.309
# [epoch: 1, batches: 10773] loss: 0.296
# [epoch: 1, batches: 10906] loss: 0.303
# [epoch: 1, batches: 11039] loss: 0.291
# [epoch: 2, batches: 133] loss: 0.286
# [epoch: 2, batches: 266] loss: 0.293
# [epoch: 2, batches: 399] loss: 0.294
# [epoch: 2, batches: 532] loss: 0.304
# [epoch: 2, batches: 665] loss: 0.292
# [epoch: 2, batches: 798] loss: 0.296
# [epoch: 2, batches: 931] loss: 0.304
# [epoch: 2, batches: 1064] loss: 0.305
# [epoch: 2, batches: 1197] loss: 0.290
# [epoch: 2, batches: 1330] loss: 0.299
# [epoch: 2, batches: 1463] loss: 0.297
# [epoch: 2, batches: 1596] loss: 0.291
# [epoch: 2, batches: 1729] loss: 0.307
# [epoch: 2, batches: 1862] loss: 0.293
# [epoch: 2, batches: 1995] loss: 0.291
# [epoch: 2, batches: 2128] loss: 0.295
# [epoch: 2, batches: 2261] loss: 0.309
# [epoch: 2, batches: 2394] loss: 0.289
# [epoch: 2, batches: 2527] loss: 0.286
# [epoch: 2, batches: 2660] loss: 0.291
# [epoch: 2, batches: 2793] loss: 0.281
# [epoch: 2, batches: 2926] loss: 0.287
# [epoch: 2, batches: 3059] loss: 0.273
# [epoch: 2, batches: 3192] loss: 0.291
# [epoch: 2, batches: 3325] loss: 0.281
# [epoch: 2, batches: 3458] loss: 0.282
# [epoch: 2, batches: 3591] loss: 0.284
# [epoch: 2, batches: 3724] loss: 0.303
# [epoch: 2, batches: 3857] loss: 0.291
# [epoch: 2, batches: 3990] loss: 0.288
# [epoch: 2, batches: 4123] loss: 0.291
# [epoch: 2, batches: 4256] loss: 0.275
# [epoch: 2, batches: 4389] loss: 0.282
# [epoch: 2, batches: 4522] loss: 0.282
# [epoch: 2, batches: 4655] loss: 0.294
# [epoch: 2, batches: 4788] loss: 0.280
# [epoch: 2, batches: 4921] loss: 0.285
# [epoch: 2, batches: 5054] loss: 0.287
# [epoch: 2, batches: 5187] loss: 0.272
# [epoch: 2, batches: 5320] loss: 0.291
# [epoch: 2, batches: 5453] loss: 0.281
# [epoch: 2, batches: 5586] loss: 0.266
# [epoch: 2, batches: 5719] loss: 0.279
# [epoch: 2, batches: 5852] loss: 0.283
# [epoch: 2, batches: 5985] loss: 0.280
# [epoch: 2, batches: 6118] loss: 0.277
# [epoch: 2, batches: 6251] loss: 0.281
# [epoch: 2, batches: 6384] loss: 0.284
# [epoch: 2, batches: 6517] loss: 0.279
# [epoch: 2, batches: 6650] loss: 0.280
# [epoch: 2, batches: 6783] loss: 0.283
# [epoch: 2, batches: 6916] loss: 0.279
# [epoch: 2, batches: 7049] loss: 0.285
# [epoch: 2, batches: 7182] loss: 0.298
# [epoch: 2, batches: 7315] loss: 0.287
# [epoch: 2, batches: 7448] loss: 0.281
# [epoch: 2, batches: 7581] loss: 0.288
# [epoch: 2, batches: 7714] loss: 0.271
# [epoch: 2, batches: 7847] loss: 0.278
# [epoch: 2, batches: 7980] loss: 0.289
# [epoch: 2, batches: 8113] loss: 0.285
# [epoch: 2, batches: 8246] loss: 0.250
# [epoch: 2, batches: 8379] loss: 0.274
# [epoch: 2, batches: 8512] loss: 0.279
# [epoch: 2, batches: 8645] loss: 0.286
# [epoch: 2, batches: 8778] loss: 0.280
# [epoch: 2, batches: 8911] loss: 0.277
# [epoch: 2, batches: 9044] loss: 0.281
# [epoch: 2, batches: 9177] loss: 0.288
# [epoch: 2, batches: 9310] loss: 0.282
# [epoch: 2, batches: 9443] loss: 0.259
# [epoch: 2, batches: 9576] loss: 0.277
# [epoch: 2, batches: 9709] loss: 0.281
# [epoch: 2, batches: 9842] loss: 0.276
# [epoch: 2, batches: 9975] loss: 0.278
# [epoch: 2, batches: 10108] loss: 0.282
# [epoch: 2, batches: 10241] loss: 0.280
# [epoch: 2, batches: 10374] loss: 0.285
# [epoch: 2, batches: 10507] loss: 0.269
# [epoch: 2, batches: 10640] loss: 0.264
# [epoch: 2, batches: 10773] loss: 0.262
# [epoch: 2, batches: 10906] loss: 0.278
# [epoch: 2, batches: 11039] loss: 0.267
# Done with training.
# Accuracy of 1000 batches: 91 %
# Accuracy of 2000 batches: 91 %
# Accuracy of 3000 batches: 90 %
# Accuracy of 4000 batches: 90 %
# Accuracy of 5000 batches: 90 %
# Accuracy of 6000 batches: 90 %
# Accuracy of 7000 batches: 90 %
# Accuracy of 8000 batches: 90 %
# Accuracy of 9000 batches: 90 %
# Accuracy of 10000 batches: 90 %
# Accuracy of 11000 batches: 90 %
# Accuracy of 12000 batches: 90 %
# Accuracy of 13000 batches: 90 %
# Accuracy of 14000 batches: 90 %
# Accuracy of 15000 batches: 90 %
# Accuracy of 16000 batches: 90 %
# Accuracy of 17000 batches: 90 %
# Accuracy of 18000 batches: 90 %
# Accuracy of 19000 batches: 90 %
# Accuracy of 20000 batches: 90 %
# Accuracy of 21000 batches: 90 %
# Accuracy of 22000 batches: 90 %
# Accuracy of 23000 batches: 90 %
# Accuracy of 24000 batches: 90 %
# Accuracy of 25000 batches: 90 %
# Accuracy of 26000 batches: 90 %
# Accuracy of 27000 batches: 90 %
# Accuracy of 28000 batches: 90 %
# Accuracy of 29000 batches: 90 %
# Accuracy of 30000 batches: 90 %
# Accuracy of 31000 batches: 90 %
# Accuracy of 32000 batches: 90 %
# Accuracy of 33000 batches: 90 %
# Accuracy of 34000 batches: 90 %
# Accuracy of 35000 batches: 90 %
# Accuracy of 36000 batches: 90 %
# Accuracy of 37000 batches: 90 %
# Accuracy of 38000 batches: 90 %
# Accuracy of 39000 batches: 90 %
# Accuracy of 40000 batches: 90 %
# Accuracy of 41000 batches: 90 %
# Accuracy of 42000 batches: 90 %
# Accuracy of 43000 batches: 90 %
# Accuracy of 44000 batches: 90 %
# Accuracy of 45000 batches: 90 %
# Accuracy of 46000 batches: 90 %
# Accuracy of 47000 batches: 90 %
# Accuracy of 48000 batches: 90 %
# Accuracy of 49000 batches: 90 %
# Accuracy of 50000 batches: 90 %
# Accuracy of 51000 batches: 90 %
# Accuracy of 52000 batches: 90 %
# Accuracy of 53000 batches: 90 %
# Accuracy of 54000 batches: 90 %
# Accuracy of 55000 batches: 90 %
# Accuracy of 56000 batches: 90 %
# Accuracy of 57000 batches: 90 %
# Accuracy of 58000 batches: 90 %
# Accuracy of 59000 batches: 90 %
# Accuracy of 60000 batches: 90 %
# Accuracy of 61000 batches: 90 %
# Accuracy of 62000 batches: 90 %
# Accuracy of 63000 batches: 90 %
# Accuracy of 64000 batches: 90 %
# Accuracy of 65000 batches: 90 %
# Accuracy of 66000 batches: 90 %
# Accuracy of 67000 batches: 90 %
# Accuracy of 68000 batches: 90 %
# Accuracy of 69000 batches: 90 %
# Accuracy of 70000 batches: 90 %
# Accuracy of 71000 batches: 90 %
# Accuracy of 72000 batches: 90 %
# Accuracy of 73000 batches: 90 %
# Accuracy of 74000 batches: 90 %
# Accuracy of 75000 batches: 90 %
# Accuracy of 76000 batches: 90 %
# Accuracy of 77000 batches: 90 %
# Accuracy of 78000 batches: 90 %
# Accuracy of 79000 batches: 90 %
# Accuracy of 80000 batches: 90 %
# Accuracy of 81000 batches: 90 %
# Accuracy of 82000 batches: 90 %
# Accuracy of 83000 batches: 90 %
# Accuracy of 84000 batches: 90 %
# Accuracy of 85000 batches: 90 %
# Accuracy of 86000 batches: 90 %
# Accuracy of 87000 batches: 90 %
# Accuracy of 88000 batches: 90 %
# Accuracy of 89000 batches: 90 %
# Accuracy of 90000 batches: 90 %
# Accuracy of 91000 batches: 90 %
# Accuracy of 92000 batches: 90 %
# Accuracy of 93000 batches: 90 %
# Accuracy of 94000 batches: 90 %
# Accuracy of 95000 batches: 90 %
# Accuracy of 96000 batches: 90 %
# Accuracy of 97000 batches: 90 %
# Accuracy of 98000 batches: 90 %
# Accuracy of 99000 batches: 90 %
# Accuracy of 100000 batches: 90 %
# Accuracy of 101000 batches: 90 %
# Accuracy of 102000 batches: 90 %
# Accuracy of 103000 batches: 90 %
# Accuracy of 104000 batches: 90 %
# Accuracy of 105000 batches: 90 %
# Forced checkpoint.

# %%
mnt.plot_confusion_matrix(y_pred=y_pred, y_true=y_true, classes=classes)

# %% [markdown]
# ### Check per-class performance

# %%
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))
for data in testloader:
    images, labels = data
    outputs = trainer.model(Variable(images))
    _, predicted = torch.max(outputs.data, 1)
    c = (predicted == labels).squeeze()
    for i in range(2):
        label = labels[i]
        class_correct[label] += c[i]
        class_total[label] += 1

for i in range(2):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))

# %% [markdown]
# ### Convolve throughout the image to generate segmented image based on trained Network

# %%
input_image = '19_test.tif'

def get_mask_file(file_name): 
    return file_name.split('_')[0] + '_test_mask.gif'

def get_ground_truth_file(file_name): 
    return file_name.split('_')[0] + '_manual1.gif'

img_obj = SegmentedImage()

img_obj.load_file(data_dir=Dirs['images'], file_name=input_image)
img_obj.res['orig'] = img_obj.image_arr[:, :, 1]
img_obj.working_arr = img_obj.image_arr[:, :, 1]
img_obj.working_arr = imgutil.whiten_image2d(img_obj.working_arr)

img_obj.load_mask(mask_dir=Dirs['mask'], fget_mask=get_mask_file, erode=True)
img_obj.load_ground_truth(gt_dir=Dirs['truth'], fget_ground_truth=get_ground_truth_file)

transform = transforms.Compose([transforms.ToTensor()])
dtest = DriveDatasetFromImageObj(img_obj=img_obj, patch_size=31, transform=transform, num_classes=2)
dclss, d_cls_count = np.unique(dtest.labels, return_counts=True)
dclass_weights = 1.0/d_cls_count
ddata_weights = np.array([dclass_weights[t] for t in dtest.labels]) 

dsampler = WeightedRandomSampler(ddata_weights, dtest.data.shape[0])
dtestloader = torch.utils.data.DataLoader(dtest, batch_size=2, shuffle=False, num_workers=2, sampler=dsampler)
# Out:
# Mask loaded: 19_test_mask.gif
# Ground truth loaded: 19_manual1.gif

# %%
trainer.model.eval()
img_obj.res['seg'] = np.zeros_like(img_obj.working_arr)
for i, j, image, label in dtestloader:
    if Flags['useGPU']:
        images = image.cuda()
        label = label.cuda()
    outputs = trainer.model(Variable(image))
    _, predicted = torch.max(outputs.data, 1)
    img_obj.res['seg'][i, j] = predicted[0] * 255

# %%
IMG.fromarray(img_obj.res['seg'])
# Out:
# <PIL.Image.Image image mode=L size=565x584 at 0x7FE112AB67F0>
